# %%
import pandas as pd

try:
    df = pd.read_csv('/kaggle/input/analyze/women_in_stem.csv')
    print("✅ Данные загружены успешно!")
    print(f"Строк: {len(df)}, Столбцов: {len(df.columns)}")
except Exception as e:
    print(f"❌ Ошибка загрузки: {e}")

# %%
print(df.head())

print(df.info())

print(df.describe())
print(df.isnull().sum())

# %%
print(df.head())


print(df.info())


print(df.describe())

print(df.isnull().sum())

# %%
df = df.dropna() 

df['Year'] = df['Year'].astype(int)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os


os.makedirs('/kaggle/working/data', exist_ok=True)
os.makedirs('/kaggle/working/figures', exist_ok=True)


processed_data_path = '/kaggle/working/data/processed_women_in_stem.csv'
df.to_csv(processed_data_path, index=False)
print(f"✅ Данные сохранены: {processed_data_path}")


plt.figure(figsize=(12, 6))
ax = sns.countplot(data=df, x='STEM Fields', palette='viridis')


for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title('Распределение данных по STEM-направлениям', pad=20)
plt.xlabel('Область STEM')
plt.ylabel('Количество записей')
plt.xticks(rotation=45)


figure_path = '/kaggle/working/figures/stem_fields_distribution.png'
plt.savefig(figure_path, dpi=300, bbox_inches='tight')
print(f"✅ График сохранен: {figure_path}")
plt.show()


print("\n📂 Содержимое рабочей директории:")
# !ls -lh /kaggle/working/
print("\n📂 Содержимое папки data:")
# !ls -lh /kaggle/working/data/
print("\n📂 Содержимое папки figures:")
# !ls -lh /kaggle/working/figures/
